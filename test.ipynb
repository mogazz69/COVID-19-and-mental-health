# %%
import pandas as pd
import numpy as np
import datetime

# %%
mental_df = pd.read_csv("Resources/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")
mental_df.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Phase  Time Period     Time Period Label  \
# 0  United States     1            1  Apr 23 - May 5, 2020
# 1  18 - 29 years     1            1  Apr 23 - May 5, 2020
# 2  30 - 39 years     1            1  Apr 23 - May 5, 2020
# 3  40 - 49 years     1            1  Apr 23 - May 5, 2020
# 4  50 - 59 years     1            1  Apr 23 - May 5, 2020
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0             04/23/2020           05/05/2020   23.5    22.7     24.3
# 1             04/23/2020           05/05/2020   32.7    30.2     35.2
# 2             04/23/2020           05/05/2020   25.7    24.1     27.3
# 3             04/23/2020           05/05/2020   24.8    23.3     26.2
# 4             04/23/2020           05/05/2020   23.2    21.5     25.0
#
#   Confidence Interval Quartile Range
# 0         22.7 - 24.3            NaN
# 1         30.2 - 35.2            NaN
# 2         24.1 - 27.3            NaN
# 3         23.3 - 26.2            NaN
# 4         21.5 - 25.0            NaN

# %%
mental_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8901 entries, 0 to 8900
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               8901 non-null   object
#  1   Group                   8901 non-null   object
#  2   State                   8901 non-null   object
#  3   Subgroup                8901 non-null   object
#  4   Phase                   8901 non-null   object
#  5   Time Period             8901 non-null   int64
#  6   Time Period Label       8901 non-null   object
#  7   Time Period Start Date  8901 non-null   object
#  8   Time Period End Date    8901 non-null   object
#  9   Value                   8604 non-null   float64
#  10  Low CI                  8604 non-null   float64
#  11  High CI                 8604 non-null   float64
#  12  Confidence Interval     8604 non-null   object
#  13  Quartile Range          6120 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 973.7+ KB

# %%
mental_df=mental_df.drop(columns=["Low CI", "High CI", "Confidence Interval", "Quartile Range", "Phase", "Time Period", "Time Period End Date", "Time Period Label"])

# %%
mental_df.to_csv("Resources/Almost_Clean.csv")

# %%
mental_df.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Time Period Start Date  Value
# 0  United States             04/23/2020   23.5
# 1  18 - 29 years             04/23/2020   32.7
# 2  30 - 39 years             04/23/2020   25.7
# 3  40 - 49 years             04/23/2020   24.8
# 4  50 - 59 years             04/23/2020   23.2

# %%
mental_df['Time Period Start Date'] = pd.to_datetime(mental_df['Time Period Start Date'])
mental_df['Time Period Start Date'] = pd.to_datetime(mental_df['Time Period Start Date'],format='%Y%m%d')
mental_df['year'] = pd.DatetimeIndex(mental_df['Time Period Start Date']).year
mental_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8901 entries, 0 to 8900
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               8901 non-null   object
#  1   Group                   8901 non-null   object
#  2   State                   8901 non-null   object
#  3   Subgroup                8901 non-null   object
#  4   Time Period Start Date  8901 non-null   datetime64[ns]
#  5   Value                   8604 non-null   float64
#  6   year                    8901 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 486.9+ KB

# %%
mental_2020_df = mental_df.loc[(mental_df['year'] == 2020)]
mental_2021_df = mental_df.loc[(mental_df['year'] == 2021)]

# %%
mental_2020_df.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Time Period Start Date  Value  year
# 0  United States             2020-04-23   23.5  2020
# 1  18 - 29 years             2020-04-23   32.7  2020
# 2  30 - 39 years             2020-04-23   25.7  2020
# 3  40 - 49 years             2020-04-23   24.8  2020
# 4  50 - 59 years             2020-04-23   23.2  2020

# %%
mental_2021_df.head()
# Out:
#                             Indicator              Group          State  \
# 4486  Symptoms of Depressive Disorder  National Estimate  United States
# 4487  Symptoms of Depressive Disorder             By Age  United States
# 4488  Symptoms of Depressive Disorder             By Age  United States
# 4489  Symptoms of Depressive Disorder             By Age  United States
# 4490  Symptoms of Depressive Disorder             By Age  United States
#
#            Subgroup Time Period Start Date  Value  year
# 4486  United States             2021-01-06   28.4  2021
# 4487  18 - 29 years             2021-01-06   41.1  2021
# 4488  30 - 39 years             2021-01-06   31.9  2021
# 4489  40 - 49 years             2021-01-06   29.1  2021
# 4490  50 - 59 years             2021-01-06   27.1  2021

# %%
mental_2020_df.to_csv("Resources/Almost_Clean_2020.csv")
mental_2021_df.to_csv("Resources/Almost_Clean_2021.csv")

# %%
mental_2020_df['Group'].unique()
mental_2020_Depression_df=mental_2020_df.loc[(mental_df['Indicator'] == 'Symptoms of Depressive Disorder')]
mental_2020_Depression_df.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Time Period Start Date  Value  year
# 0  United States             2020-04-23   23.5  2020
# 1  18 - 29 years             2020-04-23   32.7  2020
# 2  30 - 39 years             2020-04-23   25.7  2020
# 3  40 - 49 years             2020-04-23   24.8  2020
# 4  50 - 59 years             2020-04-23   23.2  2020

# %%
mental_2020_df['Group'].unique()
mental_2020_Anxiety_df=mental_2020_df.loc[(mental_df['Indicator'] == 'Symptoms of Anxiety Disorder')]
mental_2020_Anxiety_df.head()
# Out:
#                        Indicator              Group          State  \
# 70  Symptoms of Anxiety Disorder  National Estimate  United States
# 71  Symptoms of Anxiety Disorder             By Age  United States
# 72  Symptoms of Anxiety Disorder             By Age  United States
# 73  Symptoms of Anxiety Disorder             By Age  United States
# 74  Symptoms of Anxiety Disorder             By Age  United States
#
#          Subgroup Time Period Start Date  Value  year
# 70  United States             2020-04-23   30.8  2020
# 71  18 - 29 years             2020-04-23   40.2  2020
# 72  30 - 39 years             2020-04-23   34.4  2020
# 73  40 - 49 years             2020-04-23   34.1  2020
# 74  50 - 59 years             2020-04-23   31.0  2020

# %%
mental_2020_df['Group'].unique()
mental_2020_AnxOrDPRS_df=mental_2020_df.loc[(mental_df['Indicator'] == 'Symptoms of Anxiety Disorder or Depressive Disorder')]
mental_2020_AnxOrDPRS_df.head()
# Out:
#                                              Indicator              Group  \
# 140  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 141  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
# 142  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
# 143  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
# 144  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
#
#              State       Subgroup Time Period Start Date  Value  year
# 140  United States  United States             2020-04-23   35.9  2020
# 141  United States  18 - 29 years             2020-04-23   46.8  2020
# 142  United States  30 - 39 years             2020-04-23   39.6  2020
# 143  United States  40 - 49 years             2020-04-23   38.9  2020
# 144  United States  50 - 59 years             2020-04-23   35.8  2020

# %%
mental_2021_Depression_df=mental_2021_df.loc[(mental_df['Indicator'] == 'Symptoms of Depressive Disorder')]
mental_2021_Depression_df.head()
# Out:
#                             Indicator              Group          State  \
# 4486  Symptoms of Depressive Disorder  National Estimate  United States
# 4487  Symptoms of Depressive Disorder             By Age  United States
# 4488  Symptoms of Depressive Disorder             By Age  United States
# 4489  Symptoms of Depressive Disorder             By Age  United States
# 4490  Symptoms of Depressive Disorder             By Age  United States
#
#            Subgroup Time Period Start Date  Value  year
# 4486  United States             2021-01-06   28.4  2021
# 4487  18 - 29 years             2021-01-06   41.1  2021
# 4488  30 - 39 years             2021-01-06   31.9  2021
# 4489  40 - 49 years             2021-01-06   29.1  2021
# 4490  50 - 59 years             2021-01-06   27.1  2021

# %%
mental_2021_Anxiety_df=mental_2021_df.loc[(mental_df['Indicator'] == 'Symptoms of Anxiety Disorder')]
mental_2021_Anxiety_df.head()
# Out:
#                          Indicator              Group          State  \
# 4575  Symptoms of Anxiety Disorder  National Estimate  United States
# 4576  Symptoms of Anxiety Disorder             By Age  United States
# 4577  Symptoms of Anxiety Disorder             By Age  United States
# 4578  Symptoms of Anxiety Disorder             By Age  United States
# 4579  Symptoms of Anxiety Disorder             By Age  United States
#
#            Subgroup Time Period Start Date  Value  year
# 4575  United States             2021-01-06   35.8  2021
# 4576  18 - 29 years             2021-01-06   46.3  2021
# 4577  30 - 39 years             2021-01-06   40.0  2021
# 4578  40 - 49 years             2021-01-06   40.0  2021
# 4579  50 - 59 years             2021-01-06   36.0  2021

# %%
mental_2021_AnxOrDPRS_df=mental_2021_df.loc[(mental_df['Indicator'] == 'Symptoms of Anxiety Disorder or Depressive Disorder')]
mental_2021_AnxOrDPRS_df.head()
# Out:
#                                               Indicator              Group  \
# 4664  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 4665  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
# 4666  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
# 4667  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
# 4668  Symptoms of Anxiety Disorder or Depressive Dis...             By Age
#
#               State       Subgroup Time Period Start Date  Value  year
# 4664  United States  United States             2021-01-06   41.1  2021
# 4665  United States  18 - 29 years             2021-01-06   53.5  2021
# 4666  United States  30 - 39 years             2021-01-06   45.8  2021
# 4667  United States  40 - 49 years             2021-01-06   43.9  2021
# 4668  United States  50 - 59 years             2021-01-06   40.6  2021

# %%
mental_df['Value'].describe()
#mild mod high ext
# Out:
# count    8604.000000
# mean       30.146897
# std         7.763409
# min         6.400000
# 25%        24.700000
# 50%        29.700000
# 75%        35.100000
# max        71.900000
# Name: Value, dtype: float64

# %%
for val in mental_df["Value"]:
    if val <= 24:
        mental_df["Value"] = "mild"

# %%
mental_df.to_csv("dummy_data.csv")
